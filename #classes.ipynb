# %%
class Cadastro:
  def __init__(self, nome, idade, cidade, RG, cor_pele):
      self.nome = ''
      self.idade = ''
      self.cidade = ''
      self.RG = ''
      self.cor_pele = ''

  def nome(self):
    no = input("Informe seu nome completo: ==>  ")
    
  def idade(self):
    ida = input("Informe sua idade: ==>  ")

  def cidade(self):
    ci = input("Informe sua cidade: ==>  ")

  def RG(self):
    RG = int(input("Informe os numeros do seu RG: ==>  "))

  def cor_pele(self):
    cor = input("informe a cor da sua pele: ==>  ")

  def fim(self):
    print("Obrigado(a), cadastro realizado com sucesso! ")
    



  
  nome('')
  idade('')
  cidade('')
  RG('')
  cor_pele('')
  fim('')
# Out:
# Informe seu nome: ==>  maria leones
# Informe sua idade: ==>  21
# Informe sua cidade: ==>  caetes
# Informe os numeros do seu RG: ==>  345566
# informe a cor da sua pele: ==>  parda
# Obrigado(a), cadastro realizado com sucesso!
